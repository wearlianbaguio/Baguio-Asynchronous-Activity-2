# %% [markdown]
# <a href="https://colab.research.google.com/github/wearlianbaguio/Baguio-Asynchronous-Activity-2/blob/main/Shesheshe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTING LIBRARIES
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_palette('husl')
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b55b891f-5101-4371-8125-394b63fc02ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b55b891f-5101-4371-8125-394b63fc02ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Use the correct file name after uploading
uploaded_file_name = 'Cuwurrent Filtered Data.csv'

# Read the CSV file
col_name = ['Year and Section', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5']
dataset = pd.read_csv(uploaded_file_name, names= col_name)

# %%
dataset.head(81)
# Out:
#    Year and Section  Q1  Q2  Q3  Q4  Q5
# 0           CPE 1-2   1   5   2   1   3
# 1           CPE 2-1   1   4   3   4   4
# 2           CPE 1-1   1   3   2   1   4
# 3           CPE 1-2   1   4   2   2   4
# 4           CPE 1-1   1   5   2   2   3
# ..              ...  ..  ..  ..  ..  ..
# 75          CPE 2-1   1   1   5   2   4
# 76          CPE 2-1   1   1   1   2   1
# 77          CPE 3-1   2   2   2   5   2
# 78          CPE 2-2   1   2   2   4   3
# 79          CPE 2-2   1   2   3   3   4
#
# [80 rows x 6 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_26['Q1'].plot(kind='hist', bins=20, title='Q1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27['Q2'].plot(kind='hist', bins=20, title='Q2')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_30.groupby('Year and Section').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
columns_to_plot = ['Q1', 'Q2', 'Q3', 'Q4', 'Q5']

# Create subplots
fig, axes = plt.subplots(1, len(columns_to_plot), figsize=(15, 3), sharey=True)

# Plot each bar graph
for i, column in enumerate(columns_to_plot):
    sns.countplot(y=column, data=dataset, ax=axes[i], palette='Dark2')
    axes[i].set_title(column)
    axes[i].spines['top'].set_visible(False)
    axes[i].spines['right'].set_visible(False)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-57-74a6a670f88c>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=column, data=dataset, ax=axes[i], palette='Dark2')
# <ipython-input-57-74a6a670f88c>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=column, data=dataset, ax=axes[i], palette='Dark2')
# <ipython-input-57-74a6a670f88c>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=column, data=dataset, ax=axes[i], palette='Dark2')
# <ipython-input-57-74a6a670f88c>:9: FutureWarning:
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year and Section  80 non-null     object
#  1   Q1                80 non-null     int64
#  2   Q2                80 non-null     int64
#  3   Q3                80 non-null     int64
#  4   Q4                80 non-null     int64
#  5   Q5                80 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 3.9+ KB

# %%
dataset.describe()
# Out:
#               Q1         Q2         Q3         Q4         Q5
# count  80.000000  80.000000  80.000000  80.000000  80.000000
# mean    1.200000   3.100000   2.537500   3.262500   2.937500
# std     0.537222   1.587929   1.042681   1.328783   0.890793
# min     1.000000   1.000000   1.000000   1.000000   1.000000
# 25%     1.000000   2.000000   2.000000   2.000000   2.000000
# 50%     1.000000   3.000000   2.000000   3.000000   3.000000
# 75%     1.000000   5.000000   3.000000   5.000000   4.000000
# max     4.000000   5.000000   5.000000   5.000000   5.000000

# %%
dataset['Q1'].value_counts()
# Out:
# 1    68
# 2     9
# 3     2
# 4     1
# Name: Q1, dtype: int64

# %%
dataset['Q2'].value_counts()
# Out:
# 5    25
# 1    18
# 2    17
# 4    11
# 3     9
# Name: Q2, dtype: int64

# %%
sns.pairplot(dataset, hue='Q5', markers='+')
plt.show()

# %%
X = dataset.drop(['Q2'], axis=1)
y = dataset['Q2']
print(f'X shape: {X.shape} | y shape: {y.shape} ')
# Out:
# X shape: (80, 5) | y shape: (80,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVC', SVC(gamma='auto')))
# evaluate each model in turn
results = []
model_names = []
for name, model in models:
  kfold = StratifiedKFold(n_splits=4, random_state=1, shuffle=True)
def handle_value_error(x):
    try:
        return float(x)
    except ValueError:
        return 0.0  # or any other default value that makes sense in your context

cv_results = cross_val_score(model, X_train.applymap(handle_value_error), y_train, cv=kfold, scoring='accuracy', error_score='raise')

results.append(cv_results)
model_names.append(name)
print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# SVC: 0.428571 (0.050508)

# %%
def handle_value_error(X):
    try:
        return float(X)
    except ValueError:
        CPE = ['CPE 3-2', 'CPE 2-1']
        if X == CPE:
            return 0.0  # or any other default value that makes sense in your context
        else:
            raise ValueError(f"Could not convert string to float: {X}")


X_train = X_train.applymap(handle_value_error)
model = SVC(gamma='auto')
model.fit(X_train, y_train)
prediction = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-139-a977ba832550> in handle_value_error(X)
#       2     try:
# ----> 3         return float(X)
#       4     except ValueError:
#
# ValueError: could not convert string to float: 'CPE 3-2'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-139-a977ba832550> in <cell line: 12>()
#      10
#      11
# ---> 12 X_train = X_train.applymap(handle_value_error)
#      13 model = SVC(gamma='auto')
#      14 model.fit(X_train, y_train)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in applymap(self, func, na_action, **kwargs)
#    9651             return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#    9652
# ...

# %%
print(f'Test Accuracy: {accuracy_score(y_test, prediction)}')
print(f'Classification Report: \n {classification_report(y_test, prediction)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-65c737f18fa6> in <cell line: 1>()
# ----> 1 print(f'Test Accuracy: {accuracy_score(y_test, prediction)}')
#       2 print(f'Classification Report: \n {classification_report(y_test, prediction)}')
#
# NameError: name 'prediction' is not defined
